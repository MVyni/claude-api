# %%
# Load env variables and create client
from dotenv import load_dotenv
from anthropic import Anthropic

load_dotenv()

client = Anthropic()
model = "claude-haiku-4-5"

# %%
# Helper functions
def add_user_message(messages, text):
    user_message = {"role": "user", "content": text}
    messages.append(user_message)


def add_assistant_message(messages, text):
    assistant_message = {"role": "assistant", "content": text}
    messages.append(assistant_message)


def chat(messages, system=None, temperature=1.0, stop_sequences=[]):
    params = {
        "model": model,
        "max_tokens": 1000,
        "messages": messages,
        "temperature": temperature,
        "stop_sequences": stop_sequences,
    }

    if system:
        params["system"] = system

    message = client.messages.create(**params)
    return message.content[0].text

# %%
# Function to generate a new dataset
import json


def generate_dataset():
    prompt = """
Generate a evaluation dataset for a prompt evaluation. The dataset will be used to evaluate prompts
that generate Python, JSON, or Regex specifically for AWS-related tasks. Generate an array of JSON objects,
each representing task that requires Python, JSON, or a Regex to complete.

Example output:
```json
[
    {
        "task": "Description of task",
        "format": "json" or "python" or "regex",
        "solution_criteria": "Key criteria for evaluating the solution"
    },
    ...additional
]
```

* Focus on tasks that can be solved by writing a single Python function, a single JSON object, or a regular expression.
* Focus on tasks that do not require writing much code

Please generate 3 objects.
"""

    messages = []
    add_user_message(messages, prompt)
    add_assistant_message(messages, "```json")
    text = chat(messages, stop_sequences=["```"])
    return json.loads(text)

# %%
# Generate the dataset and write it to 'dataset.json'
dataset = generate_dataset()
with open("dataset.json", "w") as f:
    json.dump(dataset, f, indent=2)

# %%
# Function to grade a test case + output using a model
def grade_by_model(test_case, output):
    eval_prompt = f"""
You are an expert AWS code reviewer. Your task is to evaluate the following AI-generated solution.

Original Task:
<task>
{test_case["task"]}
</task>

Solution to Evaluate:
<solution>
{output}
</solution>

Criteria you should use to evaluate the solution:
<criteria>
{test_case["solution_criteria"]}
</criteria>

Output Format
Provide your evaluation as a structured JSON object with the following fields, in this specific order:
- "strengths": An array of 1-3 key strengths
- "weaknesses": An array of 1-3 key areas for improvement
- "reasoning": A concise explanation of your overall assessment
- "score": A number between 1-10

Respond with JSON. Keep your response concise and direct.
Example response shape:
{{
    "strengths": string[],
    "weaknesses": string[],
    "reasoning": string,
    "score": number
}}
    """

    messages = []
    add_user_message(messages, eval_prompt)
    add_assistant_message(messages, "```json")
    eval_text = chat(messages, stop_sequences=["```"])
    return json.loads(eval_text)

# %%
# Passes a test case into Claude
def run_prompt(test_case):
    prompt = f"""
Please solve the following task:

{test_case["task"]}

* Respond only with Python, JSON, or a plain Regex
* Do not add any comments or commentary or explanation
"""

    messages = []
    add_user_message(messages, prompt)
    add_assistant_message(messages, "```code")
    output = chat(messages, stop_sequences=["```"])
    return output

# %%
# Functions to validate the output structure
import re
import ast


def validate_json(text):
    try:
        json.loads(text.strip())
        return 10
    except json.JSONDecodeError:
        return 0


def validate_python(text):
    try:
        ast.parse(text.strip())
        return 10
    except SyntaxError:
        return 0


def validate_regex(text):
    try:
        re.compile(text.strip())
        return 10
    except re.error:
        return 0


def grade_syntax(response, test_case):
    format = test_case["format"]
    if format == "json":
        return validate_json(response)
    elif format == "python":
        return validate_python(response)
    else:
        return validate_regex(response)

# %%
# Function to execute a single test case and grade the output
def run_test_case(test_case):
    """Calls run_prompt, then grades the result"""
    output = run_prompt(test_case)

    model_grade = grade_by_model(test_case, output)
    model_score = model_grade["score"]
    reasoning = model_grade["reasoning"]

    syntax_score = grade_syntax(output, test_case)

    score = (model_score + syntax_score) / 2

    return {
        "output": output,
        "test_case": test_case,
        "score": score,
        "reasoning": reasoning,
    }

# %%
from statistics import mean


def run_eval(dataset):
    """Loads the dataset and calls run_test_case with each case"""
    results = []

    for test_case in dataset:
        result = run_test_case(test_case)
        results.append(result)

    average_score = mean([result["score"] for result in results])
    print(f"Average score: {average_score}")

    return results

# %%
with open("dataset.json", "r") as f:
    dataset = json.load(f)

results = run_eval(dataset)
# Out:
# Average score: 7.833333333333333

# %%
print(json.dumps(results, indent=2))
# Out:
# [
#   {
#     "output": "\nimport re\nimport json\nimport yaml\n\ndef extract_s3_buckets(template_string):\n    buckets = set()\n    \n    # Try to parse as JSON first\n    try:\n        template = json.loads(template_string)\n    except:\n        # Try to parse as YAML\n        try:\n            template = yaml.safe_load(template_string)\n        except:\n            # Fallback to regex\n            pattern = r'\"BucketName\"\\s*:\\s*\"([^\"]+)\"|\"Bucket\"\\s*:\\s*\"([^\"]+)\"|S3Bucket[\"\\s:]*\"([^\"]+)\"'\n            matches = re.findall(pattern, template_string)\n            return [m[0] or m[1] or m[2] for m in matches if any(m)]\n    \n    # Extract from parsed template\n    def find_buckets(obj, buckets_set):\n        if isinstance(obj, dict):\n            for key, value in obj.items():\n                if key in ['BucketName', 'Bucket', 'S3Bucket', 'DestinationBucket', 'SourceBucket']:\n                    if isinstance(value, str):\n                        buckets_set.add(value)\n                find_buckets(value, buckets_set)\n        elif isinstance(obj, list):\n            for item in obj:\n                find_buckets(item, buckets_set)\n    \n    find_buckets(template, buckets)\n    return list(buckets)\n",
#     "test_case": {
#       "task": "Extract all AWS S3 bucket names from a CloudFormation template string",
#       "format": "regex",
#       "solution_criteria": "The regex should accurately match S3 bucket logical IDs or references in CloudFormation syntax (e.g., 'AWS::S3::Bucket' resources and their names). Should handle variations in whitespace and quotes."
#     },
#     "score": 7.5,
#     "reasoning": "The solution demonstrates good multi-format parsing and recursive traversal, but falls short of the stated criteria to extract 'S3 bucket logical IDs or references in CloudFormation syntax'. It primarily finds hardcoded bucket name strings in property values rather than handling the typical CloudFormation pattern of using Ref/GetAtt to reference bucket logical IDs. For a production CloudFormation template extractor, this would miss many real-world bucket references. The regex fallback is also underdeveloped and doesn't meaningfully contribute to the solution."
#   },
#   {
#     "output": "\nimport json\nimport sys\n\ndef extract_allowed_actions(policy_doc, resource_arn):\n    \"\"\"\n    Parse an AWS IAM policy JSON document and extract all allowed actions for a specific resource.\n    \n    Args:\n        policy_doc: AWS IAM policy as a JSON string or dict\n        resource_arn: The resource ARN to filter by\n    \n    Returns:\n        List of allowed actions for the specified resource\n    \"\"\"\n    if isinstance(policy_doc, str):\n        policy = json.loads(policy_doc)\n    else:\n        policy = policy_doc\n    \n    allowed_actions = []\n    \n    if 'Statement' not in policy:\n        return allowed_actions\n    \n    for statement in policy['Statement']:\n        if statement.get('Effect') != 'Allow':\n            continue\n        \n        resources = statement.get('Resource', [])\n        if isinstance(resources, str):\n            resources = [resources]\n        \n        resource_match = False\n        for resource in resources:\n            if resource == resource_arn or resource == '*':\n                resource_match = True\n                break\n        \n        if not resource_match:\n            continue\n        \n        actions = statement.get('Action', [])\n        if isinstance(actions, str):\n            actions = [actions]\n        \n        allowed_actions.extend(actions)\n    \n    return allowed_actions\n\n\nif __name__ == \"__main__\":\n    policy_json = sys.stdin.read()\n    resource = sys.argv[1] if len(sys.argv) > 1 else \"*\"\n    \n    result = extract_allowed_actions(policy_json, resource)\n    print(json.dumps(result, indent=2))\n",
#     "test_case": {
#       "task": "Parse an AWS IAM policy JSON document and extract all allowed actions for a specific resource",
#       "format": "python",
#       "solution_criteria": "Function should accept an IAM policy JSON string and return a list of all Action values where Effect is 'Allow'. Should handle both single actions and wildcard patterns."
#     },
#     "score": 8.0,
#     "reasoning": "The solution correctly implements the core requirement of extracting allowed actions for a resource and handles the basic flexibility of IAM policies (string vs list formats). However, it falls short on realistic AWS use cases by not supporting wildcard pattern matching in resource ARNs, which is common in IAM policies. The lack of error handling could cause crashes on edge cases. Additionally, the solution doesn't account for 'Deny' statements or 'NotResource' clauses, which are important for accurately determining what's truly allowed."
#   },
#   {
#     "output": "\n{\n  \"Environment\": {\n    \"Variables\": {\n      \"LOG_LEVEL\": \"INFO\",\n      \"ENVIRONMENT\": \"production\",\n      \"ENABLE_XRAY_TRACING\": \"true\",\n      \"ENABLE_CLOUDWATCH_LOGS\": \"true\",\n      \"MONITORING_ENABLED\": \"true\"\n    }\n  },\n  \"TracingConfig\": {\n    \"Mode\": \"Active\"\n  },\n  \"LoggingConfig\": {\n    \"LogFormat\": \"JSON\",\n    \"LogGroup\": \"/aws/lambda/function-logs\",\n    \"ApplicationLogLevel\": \"INFO\",\n    \"SystemLogLevel\": \"INFO\"\n  },\n  \"CloudWatchLogsLogGroupConfig\": {\n    \"LogGroupName\": \"/aws/lambda/function-logs\",\n    \"RetentionInDays\": 14\n  },\n  \"Layers\": [],\n  \"EphemeralStorage\": {\n    \"Size\": 512\n  },\n  \"Timeout\": 30,\n  \"MemorySize\": 256,\n  \"Handler\": \"index.handler\",\n  \"Runtime\": \"python3.11\",\n  \"Role\": \"arn:aws:iam::ACCOUNT_ID:role/lambda-execution-role\"\n}\n",
#     "test_case": {
#       "task": "Create a JSON configuration object for an AWS Lambda function environment with standard logging and monitoring settings",
#       "format": "json",
#       "solution_criteria": "The JSON should include Environment variables for CloudWatch logging, X-Ray tracing, and Lambda insights. Should follow AWS Lambda configuration schema with proper key-value pairs."
#     },
#     "score": 8.0,
#     "reasoning": "The solution demonstrates solid understanding of Lambda logging and X-Ray tracing but falls short on Lambda Insights integration, which is a key monitoring requirement mentioned in the criteria. The configuration mixes actual AWS Lambda schema properties with application-level environment variables that serve no purpose without implementation code. The structure is mostly correct but could be optimized for AWS Lambda configuration best practices."
#   }
# ]
